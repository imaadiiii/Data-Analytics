# %%
import pandas as pd

# %%
data = {"a":[1,2,3,4],
       "b":[4,5,6,7],
       "c":["sudh" , "krish","hitesh","navin"]}

# %%
df= pd.DataFrame(data)

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   krish
# 2  3  6  hitesh
# 3  4  7   navin

# %%
df.set_index('a',inplace=True)

# %%
df
# Out:
#    b       c
# a
# 1  4    sudh
# 2  5   krish
# 3  6  hitesh
# 4  7   navin

# %%
df = df.reset_index()

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   krish
# 2  3  6  hitesh
# 3  4  7   navin

# %%
data = {"a":[1,2,3,4],
       "b":[4,5,6,7],
       "c":["sudh" , "krish","hitesh","navin"]}
df1 = pd.DataFrame(data,index = ['a','b','c','d'])

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
df1.reindex(['b','c','d','a'])
# Out:
#    a  b       c
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin
# a  1  4    sudh

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
for i,j in df1.iterrows():
    print( j)
# Out:
# a       1
# b       4
# c    sudh
# Name: a, dtype: object
# a        2
# b        5
# c    krish
# Name: b, dtype: object
# a         3
# b         6
# c    hitesh
# Name: c, dtype: object
# a        4
# b        7
# c    navin
# Name: d, dtype: object

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
list(df['a'])
# Out:
# [1, 2, 3, 4]

# %%
[i for i in df['a']]
# Out:
# [1, 2, 3, 4]

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
def test(x):
    return x.sum()
df1.apply(test,axis=0)
# Out:
# a                      10
# b                      22
# c    sudhkrishhiteshnavin
# dtype: object

# %%
df2 = df1[['a','b']]

# %%
df2
# Out:
#    a  b
# a  1  4
# b  2  5
# c  3  6
# d  4  7

# %%
df2.applymap(lambda x : x**2)
# Out:
#     a   b
# a   1  16
# b   4  25
# c   9  36
# d  16  49

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   krish
# 2  3  6  hitesh
# 3  4  7   navin

# %%
df.sort_values('c')
# Out:
#    a  b       c
# 2  3  6  hitesh
# 1  2  5   krish
# 3  4  7   navin
# 0  1  4    sudh

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   krish
# 2  3  6  hitesh
# 3  4  7   navin

# %%
df.sort_index(ascending = False)
# Out:
#    a  b       c
# 3  4  7   navin
# 2  3  6  hitesh
# 1  2  5   krish
# 0  1  4    sudh

# %%
pd.set_option("display.max_colwidth" ,1000)
df3 = pd.DataFrame({"Desc" :["Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science industry including cloud infrastructure."] })

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Desc
# ...

# %%
pd.set_option("display.max_colwidth" ,1000)
df3 = pd.DataFrame({"Desc" :["Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science industry including cloud infrastructure and real-time industry projects. This course will be taught in Hindi language." , "my name is aditya" ,"i use to learn data science "] })

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Desc
# ...

# %%
df3['len'] = df3['Desc'].apply(len)

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Desc  \
# ...

# %%
t ="i use to learn data science	"
len(t.split())
# Out:
# 6

# %%
df3['word_count'] = df3['Desc'].apply(lambda x :len(x.split()))

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Desc  \
# ...

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   krish
# 2  3  6  hitesh
# 3  4  7   navin

# %%
df['a'][0]
# Out:
# 1

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   krish
# 2  3  6  hitesh
# 3  4  7   navin

# %%
df['a'].mean()
# Out:
# 2.5

# %%
df['a'].median()
# Out:
# 2.5

# %%
df['a'].mode()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64

# %%
df['a'].std()
# Out:
# 1.2909944487358056

# %%
df['a'].sum()
# Out:
# 10

# %%
df['a'].min()
# Out:
# 1

# %%
df['a'].max()
# Out:
# 4

# %%
df['a'].var()
# Out:
# 1.6666666666666667

# %%
#Python Pandas - Window Functions
df4 = pd.DataFrame({'a' : [3,4,5,2,1,3,4,5,6]})

# %%
df4
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %%
df4['a'].rolling(window=1).mean()
# Out:
# 0    3.0
# 1    4.0
# 2    5.0
# 3    2.0
# 4    1.0
# 5    3.0
# 6    4.0
# 7    5.0
# 8    6.0
# Name: a, dtype: float64

# %%
df4['a'].rolling(window=2).mean()
# Out:
# 0    NaN
# 1    3.5
# 2    4.5
# 3    3.5
# 4    1.5
# 5    2.0
# 6    3.5
# 7    4.5
# 8    5.5
# Name: a, dtype: float64

# %%
df4['a'].rolling(window=3).mean()
# Out:
# 0         NaN
# 1         NaN
# 2    4.000000
# 3    3.666667
# 4    2.666667
# 5    2.000000
# 6    2.666667
# 7    4.000000
# 8    5.000000
# Name: a, dtype: float64

# %%
df4
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %%
df4['a'].rolling(window=3).sum()
# Out:
# 0     NaN
# 1     NaN
# 2    12.0
# 3    11.0
# 4     8.0
# 5     6.0
# 6     8.0
# 7    12.0
# 8    15.0
# Name: a, dtype: float64

# %%
df4
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %%
df4['a'].rolling(window=3).min()
# Out:
# 0    NaN
# 1    NaN
# 2    3.0
# 3    2.0
# 4    1.0
# 5    1.0
# 6    1.0
# 7    3.0
# 8    4.0
# Name: a, dtype: float64

# %%
df4['a'].rolling(window=3).max()
# Out:
# 0    NaN
# 1    NaN
# 2    5.0
# 3    5.0
# 4    5.0
# 5    3.0
# 6    4.0
# 7    5.0
# 8    6.0
# Name: a, dtype: float64

# %%
df4['a'].cumsum()
# Out:
# 0     3
# 1     7
# 2    12
# 3    14
# 4    15
# 5    18
# 6    22
# 7    27
# 8    33
# Name: a, dtype: int64

# %%
df4
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %%
#Python Pandas - Date Functionality

date = pd.date_range(start='2024-04-23' , end = '2024-06-23')

# %%
date
# Out:
# DatetimeIndex(['2024-04-23', '2024-04-24', '2024-04-25', '2024-04-26',
#                '2024-04-27', '2024-04-28', '2024-04-29', '2024-04-30',
#                '2024-05-01', '2024-05-02', '2024-05-03', '2024-05-04',
#                '2024-05-05', '2024-05-06', '2024-05-07', '2024-05-08',
#                '2024-05-09', '2024-05-10', '2024-05-11', '2024-05-12',
#                '2024-05-13', '2024-05-14', '2024-05-15', '2024-05-16',
#                '2024-05-17', '2024-05-18', '2024-05-19', '2024-05-20',
#                '2024-05-21', '2024-05-22', '2024-05-23', '2024-05-24',
#                '2024-05-25', '2024-05-26', '2024-05-27', '2024-05-28',
#                '2024-05-29', '2024-05-30', '2024-05-31', '2024-06-01',
#                '2024-06-02', '2024-06-03', '2024-06-04', '2024-06-05',
#                '2024-06-06', '2024-06-07', '2024-06-08', '2024-06-09',
#                '2024-06-10', '2024-06-11', '2024-06-12', '2024-06-13',
# ...

# %%
df_date = pd.DataFrame({'date':date})

# %%
df_date.dtypes
# Out:
# date    datetime64[ns]
# dtype: object

# %%
df_date
# Out:
#          date
# 0  2024-04-23
# 1  2024-04-24
# 2  2024-04-25
# 3  2024-04-26
# 4  2024-04-27
# ..        ...
# 57 2024-06-19
# 58 2024-06-20
# 59 2024-06-21
# 60 2024-06-22
# 61 2024-06-23
#
# [62 rows x 1 columns]

# %%
df7 = pd.DataFrame({"date" : ['2023-06-23' , '2023-06-22','2023-06-20']})

# %%
df7
# Out:
#          date
# 0  2023-06-23
# 1  2023-06-22
# 2  2023-06-20

# %%
df7.dtypes
# Out:
# date    object
# dtype: object

# %%
df7['updated_date'] = pd.to_datetime(df7['date'])

# %%
df7
# Out:
#          date updated_date
# 0  2023-06-23   2023-06-23
# 1  2023-06-22   2023-06-22
# 2  2023-06-20   2023-06-20

# %%
df7.dtypes
# Out:
# date                    object
# updated_date    datetime64[ns]
# dtype: object

# %%
df7['year'] = df7['updated_date'].dt.year

# %%
df7
# Out:
#          date updated_date  year
# 0  2023-06-23   2023-06-23  2023
# 1  2023-06-22   2023-06-22  2023
# 2  2023-06-20   2023-06-20  2023

# %%
df7['day'] = df7['updated_date'].dt.day

# %%
df7
# Out:
#          date updated_date  year  day
# 0  2023-06-23   2023-06-23  2023   23
# 1  2023-06-22   2023-06-22  2023   22
# 2  2023-06-20   2023-06-20  2023   20

# %%
df7['month'] = df7['updated_date'].dt.month

# %%
df7
# Out:
#          date updated_date  year  day  month
# 0  2023-06-23   2023-06-23  2023   23      6
# 1  2023-06-22   2023-06-22  2023   22      6
# 2  2023-06-20   2023-06-20  2023   20      6

# %%
#Python Pandas –Time Delta

# %%
pd.Timedelta(days= 1,hours = 5 ,minutes = 45)
# Out:
# Timedelta('1 days 05:45:00')

# %%
dt = pd.to_datetime('2023-06-20')

# %%
td = pd.Timedelta(days = 1 )

# %%
dt+td
# Out:
# Timestamp('2023-06-21 00:00:00')

# %%
#Python Pandas - Categorical Data

data = ["sudh" , "krish" , "hitesh" , "navin","sudh" ,"sudh" ]

# %%
cat = pd.Categorical(data)

# %%
cat
# Out:
# ['sudh', 'krish', 'hitesh', 'navin', 'sudh', 'sudh']
# Categories (4, object): ['hitesh', 'krish', 'navin', 'sudh']

# %%
cat.value_counts()
# Out:
# hitesh    1
# krish     1
# navin     1
# sudh      3
# Name: count, dtype: int64

# %%
#Python Pandas – Visualization

# %%
d = pd.Series([1,2,3,3,5,6,6,8])
d
# Out:
# 0    1
# 1    2
# 2    3
# 3    3
# 4    5
# 5    6
# 6    6
# 7    8
# dtype: int64

# %%
d.plot()
# Out:
# <Axes: >

# %%
df = pd.DataFrame({'a':[3,4,5,6,7],
                  'b':[4,5,6,7,8]})

# %%
df
# Out:
#    a  b
# 0  3  4
# 1  4  5
# 2  5  6
# 3  6  7
# 4  7  8

# %%
df.plot(x= 'a',y='b')
# Out:
# <Axes: xlabel='a'>

# %%
df.plot.scatter(x= 'a',y='b')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df
# Out:
#    a  b
# 0  3  4
# 1  4  5
# 2  5  6
# 3  6  7
# 4  7  8

# %%
d = pd.Series([1,2,3,3,5,6,6,8])
d
# Out:
# 0    1
# 1    2
# 2    3
# 3    3
# 4    5
# 5    6
# 6    6
# 7    8
# dtype: int64

# %%
d.plot.pie()
# Out:
# <Axes: >
